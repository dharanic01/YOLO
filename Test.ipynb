# %%
import torch

# %%
cache_path = '/Users/anil.kumar/Documents/Pepiris/dataset/coco_dataset_v2/train.cache'
data = torch.load(cache_path, weights_only=False)
data
# Out:
# [(PosixPath('/Users/anil.kumar/Documents/Pepiris/dataset/coco_dataset_v2/images/train/hampton-in-n-out_26941448_Q01-002_8DYPt.jpg'),
#   tensor([[0.0000, 0.3854, 0.9238, 0.4714, 0.9922],
#           [0.0000, 0.2057, 0.9102, 0.3099, 0.9824],
#           [0.0000, 0.1328, 0.9102, 0.2057, 0.9785],
#           [0.0000, 0.4089, 0.8359, 0.5286, 0.9004],
#           [0.0000, 0.3802, 0.7988, 0.4557, 0.8711],
#           [0.0000, 0.3177, 0.7969, 0.3802, 0.8516],
#           [0.0000, 0.1849, 0.8125, 0.2969, 0.8965],
#           [0.0000, 0.0729, 0.4844, 0.2135, 0.5352],
#           [0.0000, 0.1276, 0.5254, 0.2891, 0.6055],
#           [0.0000, 0.2109, 0.4824, 0.3359, 0.5410],
#           [0.0000, 0.3151, 0.5098, 0.4740, 0.5742],
#           [0.0000, 0.8594, 0.6777, 0.9557, 0.7246],
#           [0.0000, 0.8542, 0.7285, 0.9635, 0.8027],
#           [0.0000, 0.7578, 0.7109, 0.8542, 0.7910],
#           [0.0000, 0.6224, 0.7363, 0.7448, 0.7832],
#           [0.0000, 0.6224, 0.6855, 0.7318, 0.7344],
# ...
